# %% [markdown]
# <a href="https://colab.research.google.com/github/maqsud1987/Data_Science/blob/main/PS_Index_metodlar.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from pandas import Series,DataFrame

# %%
usernames = {"anvar":"anvarbek223", "olim":"olimtoy", "maryam":"mary334455","javohir":"javohir445"}
emails = {"anvar":"anvar@gmail.com", "olim":"olim@mail.ru", "maryam":"mary33@gmail.com","javohir":"javohir445@gmail.com"}

data  = {
    "username":usernames,
    "email":emails
}

df = pd.DataFrame(data)
df.index
# Out:
# Index(['anvar', 'olim', 'maryam', 'javohir'], dtype='object')

# %%
arr = ['anvar', 'olim', 'maryam', 'javohir']
arr[0]
# Out:
# 'anvar'

# %%
data2 = {
    'username':{"olim":"olimjon21", "maryam":"maryam2020"},
    'email':{"olim":"olimjon21@mail.ru", "maryam":"maryam20@gmail.com"}
}
df2 = pd.concat([df,pd.DataFrame(data2)])
df2
pd.concat([df,pd.DataFrame(data2)])
# Out:
#             username                 email
# anvar    anvarbek223       anvar@gmail.com
# olim         olimtoy          olim@mail.ru
# maryam    mary334455      mary33@gmail.com
# javohir   javohir445  javohir445@gmail.com
# olim       olimjon21     olimjon21@mail.ru
# maryam    maryam2020    maryam20@gmail.com

# %%
newind = pd.Index(['olim','Nafisa','Hamida']) # index yaratildi
newind
# Out:
# Index(['olim', 'Nafisa', 'Hamida'], dtype='object')

# %%
newind.isin(df2.index) # isin - jadvallarni solishtiradi
# Out:
# array([ True, False, False])

# %%
df2.index.difference(newind) # difference - jadvallar farqi
# Out:
# Index(['anvar', 'javohir', 'maryam'], dtype='object')

# %%
newind.difference(df2.index) # yuqoridagining aksi
# Out:
# Index(['Hamida', 'Nafisa'], dtype='object')

# %%
df2.index.union(newind) # union - jadvallarni birlashtiradi
# Out:
# Index(['Hamida', 'Nafisa', 'anvar', 'javohir', 'maryam', 'maryam', 'olim',
#        'olim'],
#       dtype='object')

# %%
newind.drop('olim') # drop - o'chirish
# Out:
# Index(['Nafisa', 'Hamida'], dtype='object')

# %%
s = pd.Series([120, 85, 200, 60], index=['non', 'sut', 'guruch', 'yog'])
s.index
# Out:
# Index(['non', 'sut', 'guruch', 'yog'], dtype='object')

# %%
type(s.index)
# Out:
# pandas.core.indexes.base.Index

# %%
s
# Out:
# non       120
# sut        85
# guruch    200
# yog        60
# dtype: int64

# %%
s = pd.Series([120, 85, 200, 60], index=['non', 'sut', 'guruch', 'yog'])
'sut' in s.index
# Out:
# True

# %%
s
# Out:
# non       120
# sut        85
# guruch    200
# yog        60
# dtype: int64

# %%
s.index.name = 'Mahsulotlar'
s
# Out:
# Mahsulotlar
# non       120
# sut        85
# guruch    200
# yog        60
# dtype: int64

# %%
s.name = "Narx"
s
# Out:
# Mahsulotlar
# non       120
# sut        85
# guruch    200
# yog        60
# Name: Narx, dtype: int64

# %%
s1 = pd.Series([1,2,3], index=['a','b','c'])
s2 = pd.Series([4,5,6], index=['b','c','d'])

s1.index.union(s2.index)
s1
# Out:
# a    1
# b    2
# c    3
# dtype: int64
