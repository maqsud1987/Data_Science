# %% [markdown]
# <a href="https://colab.research.google.com/github/maqsud1987/Data_Science/blob/main/Amaliyot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
import pandas as pd

df = pd.DataFrame({
    'ism': ['Ali', 'Vali', 'Guli', 'Sami', 'Doni'],
    'shahar': ['Toshkent', 'Andijon', 'Farg\'ona', 'Toshkent', 'Namangan']
})

# %%
df
# Out:
#     ism    shahar
# 0   Ali  Toshkent
# 1  Vali   Andijon
# 2  Guli  Farg'ona
# 3  Sami  Toshkent
# 4  Doni  Namangan

# %%
df2=df['shahar'].isin(['Toshkent', 'Andijon'])
df2
# Out:
# 0     True
# 1     True
# 2    False
# 3     True
# 4    False
# Name: shahar, dtype: bool

# %%
df[df2]
# Out:
#     ism    shahar
# 0   Ali  Toshkent
# 1  Vali   Andijon
# 3  Sami  Toshkent

# %%
import pandas as pd
import numpy as np

df = pd.DataFrame({
    'ism': ['Ali', 'Vali', 'Guli', np.nan],
    'yosh': [25, np.nan, 30, 40]

})

# %%
df
# Out:
#     ism  yosh
# 0   Ali  25.0
# 1  Vali   NaN
# 2  Guli  30.0
# 3   NaN  40.0

# %%
df.dropna()
# Out:
#     ism  yosh
# 0   Ali  25.0
# 2  Guli  30.0

# %%
df.dropna(how='all')
# Out:
#     ism  yosh
# 0   Ali  25.0
# 1  Vali   NaN
# 2  Guli  30.0
# 3   NaN  40.0

# %%
import pandas as pd
import numpy as np

df = pd.DataFrame({
    'ism': ['Ali', 'Vali', 'Guli', 'Doni'],
    'yosh': [25, np.nan, 30, np.nan]
})
df
# Out:
#     ism  yosh
# 0   Ali  25.0
# 1  Vali   NaN
# 2  Guli  30.0
# 3  Doni   NaN

# %%
df['yosh'].fillna(0,inplace=True)
df
# Out:
# /tmp/ipykernel_1659/1369830092.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['yosh'].fillna(0,inplace=True)
#     ism  yosh
# 0   Ali  25.0
# 1  Vali   0.0
# 2  Guli  30.0
# 3  Doni   0.0

# %%
df['yosh']=df['yosh'].fillna(0)
df
# Out:
#     ism  yosh
# 0   Ali  25.0
# 1  Vali   0.0
# 2  Guli  30.0
# 3  Doni   0.0

# %%
import pandas as pd

df = pd.DataFrame({
    'ism': ['Ali', 'Vali', 'Ali', 'Guli', 'Vali'],
    'yosh': [25, 30, 25, 22, 30]
})
df
# Out:
#     ism  yosh
# 0   Ali    25
# 1  Vali    30
# 2   Ali    25
# 3  Guli    22
# 4  Vali    30

# %%
df.duplicated()
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# 4     True
# dtype: bool

# %%
import pandas as pd

df = pd.DataFrame({
    'ism': ['Ali', 'Vali', 'Ali', 'Guli', 'Vali'],
    'yosh': [25, 30, 25, 22, 30]
})
df
# Out:
#     ism  yosh
# 0   Ali    25
# 1  Vali    30
# 2   Ali    25
# 3  Guli    22
# 4  Vali    30

# %%
df.drop_duplicates()
# Out:
#     ism  yosh
# 0   Ali    25
# 1  Vali    30
# 3  Guli    22

# %%
import pandas as pd

df = pd.DataFrame({
    'shahar': ['Toshkent', 'Andijon', 'Toshkent', 'Namangan', 'Toshkent', 'Andijon']
})
df
# Out:
#      shahar
# 0  Toshkent
# 1   Andijon
# 2  Toshkent
# 3  Namangan
# 4  Toshkent
# 5   Andijon

# %%
df['shahar'].value_counts()
# Out:
# shahar
# Toshkent    3
# Andijon     2
# Namangan    1
# Name: count, dtype: int64

# %%
df['shahar'].unique()
# Out:
# array(['Toshkent', 'Andijon', 'Namangan'], dtype=object)

# %%
import pandas as pd

df = pd.DataFrame({
    'shahar': ['Toshkent', 'Andijon', 'Toshkent', 'Namangan']
})
df
# Out:
#      shahar
# 0  Toshkent
# 1   Andijon
# 2  Toshkent
# 3  Namangan

# %%
df['shahar'].replace('Toshkent','TSH')
# Out:
# 0         TSH
# 1     Andijon
# 2         TSH
# 3    Namangan
# Name: shahar, dtype: object

# %%
df['shahar'].replace({'Toshkent':'TSH','Andijon':'AND'})
# Out:
# 0         TSH
# 1         AND
# 2         TSH
# 3    Namangan
# Name: shahar, dtype: object

# %%
import pandas as pd

df = pd.DataFrame({
    'shahar': ['Toshkent', 'Andijon', 'Namangan']
})
df
# Out:
#      shahar
# 0  Toshkent
# 1   Andijon
# 2  Namangan

# %%
df['shahar'].map(lambda x: len(x))
# Out:
# 0    8
# 1    7
# 2    8
# Name: shahar, dtype: int64

# %%
df['shahar'].map(len)
# Out:
# 0    8
# 1    7
# 2    8
# Name: shahar, dtype: int64

# %%
import pandas as pd

df = pd.DataFrame({
    'ism': ['Ali', 'Vali', 'Guli'],
    'yosh': [25, 30, 22]
})
df
# Out:
#     ism  yosh
# 0   Ali    25
# 1  Vali    30
# 2  Guli    22

# %%
df['yosh'].apply(lambda x: x+1)
# Out:
# 0    26
# 1    31
# 2    23
# Name: yosh, dtype: int64

# %%
df.rename(columns={'yosh':'age'})
# Out:
#     ism  age
# 0   Ali   25
# 1  Vali   30
# 2  Guli   22
