# %% [markdown]
# <a href="https://colab.research.google.com/github/maqsud1987/Data_Science/blob/main/Series_metodlari.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
from pandas import Series
cars_dictionary = {'Malibu':40000, 'Lacetti':20000, 'Toyota':10000, 'Mazda':5000}
models = ['Honda', 'Mazda', 'Lacetti', 'Jaguar', 'Malibu', 'Toyota''Chevrolet','Lada']
cars2 = Series(cars_dictionary, index=models)
cars2
# Out:
# Honda                  NaN
# Mazda               5000.0
# Lacetti            20000.0
# Jaguar                 NaN
# Malibu             40000.0
# ToyotaChevrolet        NaN
# Lada                   NaN
# dtype: float64

# %%
cars2.isnull() # isnul() - ro'yxatda mavjud False,yo'q bo'lsa True qayataradi
# Out:
# Honda               True
# Mazda              False
# Lacetti            False
# Jaguar              True
# Malibu             False
# ToyotaChevrolet     True
# Lada                True
# dtype: bool

# %%
cars2.notnull() #usnul() ning teskarisi
# Out:
# Honda              False
# Mazda               True
# Lacetti             True
# Jaguar             False
# Malibu              True
# ToyotaChevrolet    False
# Lada               False
# dtype: bool

# %%
cars2
# Out:
# Honda                  NaN
# Mazda               5000.0
# Lacetti            20000.0
# Jaguar                 NaN
# Malibu             40000.0
# ToyotaChevrolet        NaN
# Lada                   NaN
# dtype: float64

# %%
cars_dictionary
# Out:
# {'Malibu': 40000, 'Lacetti': 20000, 'Toyota': 10000, 'Mazda': 5000}

# %%
cars_dictionary+cars2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_4212/915885216.py in <cell line: 0>()
# ----> 1 cars_dictionary+cars2
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/ops/common.py in new_method(self, other)
#      74         other = item_from_zerodim(other)
#      75
# ---> 76         return method(self, other)
#      77
#      78     return new_method
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/arraylike.py in __radd__(self, other)
#     188     @unpack_zerodim_and_defer("__radd__")
#     189     def __radd__(self, other):
# --> 190         return self._arith_method(other, roperator.radd)
#     191
#     192     @unpack_zerodim_and_defer("__sub__")
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/series.py in _arith_method(self, other, op)
#    6133     def _arith_method(self, other, op):
# ...
